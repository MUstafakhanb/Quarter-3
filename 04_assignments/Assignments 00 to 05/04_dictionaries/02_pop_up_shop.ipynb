# %%
print("02_pop_up_shop")

def main():
    fruit_prices = {
        "apple": 3.5,
        "durian": 15.0,
        "jackfruit": 20.0,
        "kiwi": 2.5,
        "rambutan": 5.0,
        "mango": 7.0
    }

    total_cost = 0
    for fruit, price in fruit_prices.items():
        quantity = int(input(f"How many ({fruit}) do you want?: "))
        total_cost += quantity * price
    print(f"\nYour total is ${total_cost:.2f}")

if __name__ == '__main__':
    main()
# Out:
# 02_pop_up_shop
# How many (apple) do you want?: 9
# How many (durian) do you want?: 9
# How many (jackfruit) do you want?: 9
# How many (kiwi) do you want?: 9
# How many (rambutan) do you want?: 9
# How many (mango) do you want?: 9
#
# Your total is $477.00

# %%
def main():
    for num in range(10,30):
        if num % 2 == 0:
          print(f'{num} even')
        else:
          print(f'{num} odd')

if __name__ == "__main__":
  main()
# Out:
# 10 even
# 11 odd
# 12 even
# 13 odd
# 14 even
# 15 odd
# 16 even
# 17 odd
# 18 even
# 19 odd
# 20 even
# 21 odd
# 22 even
# 23 odd
# 24 even
# 25 odd
# 26 even
# 27 odd
# 28 even
# 29 odd

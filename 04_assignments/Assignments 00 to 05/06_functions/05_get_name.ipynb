# %%
print("05_get_name")

def get_name():
    return "Sophia"

def main():
    name = get_name()
    print("Howdy", name, "! 🤠")

if __name__ == '__main__':
    main()
# Out:
# 05_get_name
# Howdy Sophia ! 🤠

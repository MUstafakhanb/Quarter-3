# %%
print("02_e_mc2")

def energy():
  c:int = 29979458
  m:int = float(input("Enter kilos of mass: "))
  print("e = m*c^2")
  print("Mass =" +str (m) + "kg")
  print("C =" +str (c) + "m/s")
  print("e =" +str (m*c**2) + "jules")

if __name__ == "__main__":
  energy()
# Out:
# 02_e_mc2
# Enter kilos of mass: 130
# e = m*c^2
# Mass =130.0kg
# C =29979458m/s
# e =1.1683982725658931e+17jules

# %%
import random
print("05_random_number")

def main():
  for i in range (10):
    num:list[int] = random.randint(1,100)
    print(num)

if __name__ == '__main__':
    main()
# Out:
# 05_random_number
# 19
# 80
# 72
# 31
# 25
# 11
# 90
# 92
# 69
# 13

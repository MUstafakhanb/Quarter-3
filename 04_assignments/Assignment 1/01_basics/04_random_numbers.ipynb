# %%
import random
print("04_random_number")

def main():
  for i in range (10):
    num:list[int] = random.randint(1,100)
    print(num)

if __name__ == '__main__':
    main()
# Out:
# 04_random_number
# 52
# 22
# 49
# 4
# 73
# 88
# 10
# 45
# 29
# 4
